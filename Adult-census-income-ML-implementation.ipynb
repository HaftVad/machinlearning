# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from matplotlib import pyplot as plt 
from sklearn import preprocessing
import os
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.svm import SVC
import xgboost as xgb
import lightgbm as lgb
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from pytorch_tabnet.tab_model import TabNetClassifier

# %%
census_data = pd.read_csv('C:\MyFiles/adult.csv')
census_data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
census_data.shape
# Out:
# (32561, 15)

# %%
census_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
census_data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
census_data = census_data[census_data['workclass'].str.contains("\?") == False]
census_data = census_data[census_data['occupation'].str.contains("\?") == False]
census_data = census_data[census_data['native.country'].str.contains("\?") == False]
census_data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
# 5      Other-service      Unmarried  White  Female             0
# 6       Adm-clerical      Unmarried  White    Male             0
#
#    capital.loss  hours.per.week native.country income
# 1          4356              18  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K
# 5          3770              45  United-States  <=50K
# 6          3770              40  United-States  <=50K

# %%
print(len(census_data))
# Out:
# 30162

# %%
df = pd.DataFrame(census_data)

#33 Select the columns for Z-score calculation
columns_to_check = ['fnlwgt', 'capital.gain', 'capital.loss']

# Calculate Z-scores for each column
for col in columns_to_check:
    z_scores = np.abs(stats.zscore(df[col]))
    df = df[z_scores < 3]

print(len(df))
# Out:
# 28273

# %%
df
# Out:
#        age  workclass  fnlwgt     education  education.num  \
# 1470    62  Local-gov  159908     Bachelors             13
# 1471    72  Local-gov  144515     Doctorate             16
# 1473    66    Private  350498  Some-college             10
# 1474    33  Local-gov  262042       HS-grad              9
# 1475    29    Private  138190       HS-grad              9
# ...    ...        ...     ...           ...            ...
# 32556   22    Private  310152  Some-college             10
# 32557   27    Private  257302    Assoc-acdm             12
# 32558   40    Private  154374       HS-grad              9
# 32559   58    Private  151910       HS-grad              9
# 32560   22    Private  201490       HS-grad              9
#
#            marital.status         occupation   relationship   race     sex  \
# 1470   Married-civ-spouse       Adm-clerical           Wife  White  Female
# 1471   Married-civ-spouse    Exec-managerial        Husband  White    Male
# 1473   Married-civ-spouse   Transport-moving        Husband  White    Male
# 1474             Divorced       Adm-clerical      Own-child  White  Female
# 1475        Never-married              Sales      Unmarried  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556       Never-married    Protective-serv  Not-in-family  White    Male
# 32557  Married-civ-spouse       Tech-support           Wife  White  Female
# 32558  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32559             Widowed       Adm-clerical      Unmarried  White  Female
# 32560       Never-married       Adm-clerical      Own-child  White    Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# 1470              0          1258              38  United-States  <=50K
# 1471              0          1258              40  United-States  <=50K
# 1473              0          1258              20  United-States  <=50K
# 1474              0          1138              40  United-States  <=50K
# 1475              0          1138              40  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              40  United-States  <=50K
# 32557             0             0              38  United-States  <=50K
# 32558             0             0              40  United-States   >50K
# 32559             0             0              40  United-States  <=50K
# 32560             0             0              20  United-States  <=50K
#
# [28273 rows x 15 columns]

# %%
all_feature_cols = [
     'workclass', 
     'education',
     'education.num',
     'marital.status', 
     'occupation', 
     'relationship', 
    'race', 
    'sex',
#     'capital_gain', 
#     'capital_loss', 
    'native.country',
    'income'
]
label_encoder = preprocessing.LabelEncoder()

for c in all_feature_cols:
    t = census_data[c].unique()
    census_data[c]= label_encoder.fit_transform(census_data[c])   
    census_data[c].unique()

# %%
import seaborn as sns
sns.heatmap(census_data.corr())
plt.savefig("myplot.png")

# %%
census_data = pd.get_dummies(df, drop_first=True)
census_data.head()
# Out:
#       age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1470   62  159908             13             0          1258              38
# 1471   72  144515             16             0          1258              40
# 1473   66  350498             10             0          1258              20
# 1474   33  262042              9             0          1138              40
# 1475   29  138190              9             0          1138              40
#
#       workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 1470                 True              False                   False
# 1471                 True              False                   False
# 1473                False               True                   False
# 1474                 True              False                   False
# 1475                False               True                   False
#
#       workclass_Self-emp-not-inc  ...  native.country_Puerto-Rico  \
# 1470                       False  ...                       False
# 1471                       False  ...                       False
# 1473                       False  ...                       False
# 1474                       False  ...                       False
# 1475                       False  ...                       False
#
#       native.country_Scotland  native.country_South  native.country_Taiwan  \
# 1470                    False                 False                  False
# 1471                    False                 False                  False
# 1473                    False                 False                  False
# 1474                    False                 False                  False
# 1475                    False                 False                  False
#
#       native.country_Thailand  native.country_Trinadad&Tobago  \
# 1470                    False                           False
# 1471                    False                           False
# 1473                    False                           False
# 1474                    False                           False
# 1475                    False                           False
#
#       native.country_United-States  native.country_Vietnam  \
# 1470                          True                   False
# 1471                          True                   False
# 1473                          True                   False
# 1474                          True                   False
# 1475                          True                   False
#
#       native.country_Yugoslavia  income_>50K
# 1470                      False        False
# 1471                      False        False
# 1473                      False        False
# 1474                      False        False
# 1475                      False        False
#
# [5 rows x 96 columns]

# %%
X = census_data.iloc[:,:-1]
y = census_data.iloc[:,-1]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y, test_size=0.3)

# %%
dt_clf = DecisionTreeClassifier(random_state=24)
dt_clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=24)

# %%
test_pred = dt_clf.predict(X_test)

# %%
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.87      0.88      0.87      6509
#         True       0.58      0.56      0.57      1973
#
#     accuracy                           0.80      8482
#    macro avg       0.72      0.72      0.72      8482
# weighted avg       0.80      0.80      0.80      8482

# %% [markdown]
# ### Implementation Two - with pruning ccp_alpha=0.0001

# %%
dt_clf = DecisionTreeClassifier(random_state=24, ccp_alpha=0.0001)
dt_clf.fit(X_train,Y_train)
test_pred = dt_clf.predict(X_test)
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.88      0.91      6915
#         True       0.58      0.70      0.63      1567
#
#     accuracy                           0.85      8482
#    macro avg       0.75      0.79      0.77      8482
# weighted avg       0.86      0.85      0.85      8482

# %%
plt.figure(figsize=(15,12))
plot_tree(dt_clf, filled=True)
plt.show()

# %% [markdown]
# ### Implementation Three - with pruning ccp_alpha=0.01 - 84% accuracy

# %%
dt_clf = DecisionTreeClassifier(random_state=24, ccp_alpha=0.01)
dt_clf.fit(X_train,Y_train)
test_pred = dt_clf.predict(X_test)
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.87      0.91      7204
#         True       0.49      0.74      0.59      1278
#
#     accuracy                           0.85      8482
#    macro avg       0.72      0.80      0.75      8482
# weighted avg       0.88      0.85      0.86      8482

# %% [markdown]
# ### Random Forest Implementation

# %% [markdown]
# ### Implementation One - with no pruning - 85% accuracy

# %%
rf_clf = RandomForestClassifier(random_state=24)
rf_clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=24)

# %%
test_pred = rf_clf.predict(X_test)

# %%
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.89      0.90      6860
#         True       0.59      0.69      0.63      1622
#
#     accuracy                           0.85      8482
#    macro avg       0.75      0.79      0.77      8482
# weighted avg       0.86      0.85      0.85      8482

# %% [markdown]
# ### Implementation Two - with n_estimators - 85% accuracy

# %%
rf_clf = RandomForestClassifier(random_state=24, n_estimators =80)
rf_clf.fit(X_train,Y_train)
test_pred = rf_clf.predict(X_test)
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.89      0.90      6863
#         True       0.59      0.69      0.63      1619
#
#     accuracy                           0.85      8482
#    macro avg       0.76      0.79      0.77      8482
# weighted avg       0.86      0.85      0.85      8482

# %% [markdown]
# ### Implementation Three - with pruning ccp_alpha=0.0001 - 86% accuracy

# %%
rf_clf = RandomForestClassifier(random_state=24, ccp_alpha=0.0001)
rf_clf.fit(X_train,Y_train)
test_pred = rf_clf.predict(X_test)
print(classification_report(test_pred, Y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.94      0.88      0.91      6994
#         True       0.58      0.74      0.65      1488
#
#     accuracy                           0.86      8482
#    macro avg       0.76      0.81      0.78      8482
# weighted avg       0.88      0.86      0.87      8482

# %%
# Define XGBoost model parameters 
xgb_params = {
    'objective': 'binary:logistic',  # Assuming binary classification
    'random_state': 24,  # Set the same random state
    'learning_rate': 0.1,  # Adjust learning rate as needed
    'max_depth': 5,  # Adjust max depth as needed
}

# Create DMatrix for XGBoost (assuming pandas DataFrames)
dtrain = xgb.DMatrix(X_train, label=Y_train)
dtest = xgb.DMatrix(X_test)

# Train the XGBoost model
xgb_model = xgb.train(xgb_params, dtrain)

# Make predictions with XGBoost model
test_pred = xgb_model.predict(dtest)

# %%
threshold = 0.5
test_pred_categorical = [1 if p >= threshold else 0 for p in test_pred]

# Print classification report
print(classification_report(Y_test, test_pred_categorical))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      0.97      0.91      6520
#         True       0.82      0.43      0.56      1962
#
#     accuracy                           0.85      8482
#    macro avg       0.83      0.70      0.73      8482
# weighted avg       0.84      0.85      0.83      8482

# %%
params = {
    'objective': 'binary',  # For binary classification
    'metric': 'binary_logloss',
    'num_leaves': 31,
    'learning_rate': 0.05,
}

# Create the LightGBM dataset
train_data = lgb.Dataset(X_train, label=Y_train)
test_data = lgb.Dataset(X_test, label=Y_test)

# Train the model
model = lgb.train(params, train_data, valid_sets=[train_data,test_data])

# Make predictions
y_pred = model.predict(X_test)
# Out:
# [LightGBM] [Info] Number of positive: 4546, number of negative: 15245
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004931 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 19791, number of used features: 80
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.229700 -> initscore=-1.210004
# [LightGBM] [Info] Start training from score -1.210004

# %%
# Evaluate the model
threshold = 0.5
test_pred_categorical = [1 if p >= threshold else 0 for p in test_pred]

# Print classification report
print(classification_report(Y_test, test_pred_categorical))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      0.97      0.91      6520
#         True       0.82      0.43      0.56      1962
#
#     accuracy                           0.85      8482
#    macro avg       0.83      0.70      0.73      8482
# weighted avg       0.84      0.85      0.83      8482

# %%
#using elbow for optimal number of k
# Iterate through different values of K
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++',n_init="auto", random_state=42)
    kmeans.fit(X_train)
    wcss.append(kmeans.inertia_)

# Plot   

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=2)

# Train the model on the training data
knn.fit(X_train, Y_train)

y_pred = knn.predict(X_test)

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.81      0.95      0.87      6520
#         True       0.61      0.25      0.35      1962
#
#     accuracy                           0.79      8482
#    macro avg       0.71      0.60      0.61      8482
# weighted avg       0.76      0.79      0.75      8482

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model on the training data
knn.fit(X_train, Y_train)

y_pred = knn.predict(X_test)

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.81      0.89      0.85      6520
#         True       0.47      0.33      0.38      1962
#
#     accuracy                           0.76      8482
#    macro avg       0.64      0.61      0.62      8482
# weighted avg       0.73      0.76      0.74      8482

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# Train the model on the training data
knn.fit(X_train, Y_train)

y_pred = knn.predict(X_test)

print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.81      0.96      0.88      6520
#         True       0.64      0.23      0.34      1962
#
#     accuracy                           0.79      8482
#    macro avg       0.72      0.60      0.61      8482
# weighted avg       0.77      0.79      0.75      8482

# %%
clf = GaussianNB(var_smoothing=1e-10)

# Train the model
clf.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred = clf.predict(X_test)

# Evaluate the model's performance using classification_report
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      0.94      0.89      6520
#         True       0.69      0.46      0.55      1962
#
#     accuracy                           0.83      8482
#    macro avg       0.77      0.70      0.72      8482
# weighted avg       0.81      0.83      0.81      8482

# %%
# Initialize the Bernoulli Naive Bayes classifier
clf = BernoulliNB(alpha=0.9)

# Train the model 
clf.fit(X_train, Y_train)

# Make predictions on the testing set 
y_pred = clf.predict(X_test)

# Evaluate the model's performance using classification_report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.82      0.86      6520
#         True       0.55      0.72      0.62      1962
#
#     accuracy                           0.80      8482
#    macro avg       0.73      0.77      0.74      8482
# weighted avg       0.82      0.80      0.81      8482

# %%
# Initialize the Multinomial Naive Bayes classifier
clf = MultinomialNB(alpha=1e-5)

# Train the model 
clf.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred = clf.predict(X_test)

# Evaluate the model's performance using classification_report
print(classification_report(Y_test, y_pred,digits=3))
# Out:
#               precision    recall  f1-score   support
#
#        False      0.804     0.961     0.875      6520
#         True      0.628     0.221     0.327      1962
#
#     accuracy                          0.789      8482
#    macro avg      0.716     0.591     0.601      8482
# weighted avg      0.763     0.789     0.748      8482

# %%
clf = SVC(gamma=100)
# Linear kernel for simple cases

# Train the model
clf.fit(X_train, Y_train)

# Make predictions on the testing set
y_pred = clf.predict(X_test)

# Evaluate the model's accuracy
print(classification_report(Y_test, y_pred,digits=3,zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        False      0.776     1.000     0.874      6578
#         True      1.000     0.001     0.002      1904
#
#     accuracy                          0.776      8482
#    macro avg      0.888     0.501     0.438      8482
# weighted avg      0.826     0.776     0.678      8482
